# %% [markdown]
# # Assignment 2 — LD Score Regression (LDSC) with gwaslab
# **Goal:** Estimate SNP-based (“chip”) heritability (h²) for sqrt(HDL) using LD Score Regression, then compute a 95% confidence interval and interpret it.
#
# **Data sources**
# - GWAS summary stats: `GERA-sqrtHDL.tsv.gz` (GWAS Catalog, GCST007140)
# - LD reference panel: 1000 Genomes European (eur_w_ld_chr)
# - HapMap3 SNP list: `w_hm3.snplist` (inside eur_w_ld_chr)

# %% [markdown]
# ## Part 1: Check Environment + Files

# %%
import sys
import os
import gzip
from pathlib import Path

print("Python:", sys.version)
print("Working directory:", os.getcwd())
# Out:
# Python: 3.12.12 (main, Oct  9 2025, 11:07:00) [Clang 17.0.0 (clang-1700.4.4.1)]
# Working directory: /Users/sarahmughal/Desktop/assign2_ldsc

# %% [markdown]
# ## Part 2: Confirm Files Exist
# This notebook expects the following folder structure:
#
# - `tmp/GERA-sqrtHDL.tsv.gz`
# - `tmp/eur_w_ld_chr/` (contains LD score reference files)
# - `tmp/eur_w_ld_chr/w_hm3.snplist` (HapMap3 SNP list)

# %%
project_dir = Path(".")
tmp_dir = project_dir / "tmp"

gwas_file = tmp_dir / "GERA-sqrtHDL.tsv.gz"
hm3_list = tmp_dir / "eur_w_ld_chr" / "w_hm3.snplist"
ref_dir = tmp_dir / "eur_w_ld_chr"

print("GWAS file exists:", gwas_file.exists(), gwas_file)
print("HapMap3 list exists:", hm3_list.exists(), hm3_list)
print("Reference dir exists:", ref_dir.exists(), ref_dir)
# Out:
# GWAS file exists: True tmp/GERA-sqrtHDL.tsv.gz
# HapMap3 list exists: True tmp/eur_w_ld_chr/w_hm3.snplist
# Reference dir exists: True tmp/eur_w_ld_chr

# %%
# First few lines of the GWAS summary stats file
with gzip.open(gwas_file, "rt") as f:
    for i in range(5):
        print(f.readline().rstrip())
# Out:
# SNP_ID	chromosome	position	Allele 1	Allele 2	Effect allele (EA)	Effect allele frequency (EAF)	Sample size	Estimate Effect	P value
# rs10458597	1	564621	T	C	T	0.116	6855	-0.00873	0.54
# rs8179414	1	565400	T	C	T	0.0503	6855	-0.0261	0.21
# rs9701055	1	565433	T	C	T	0.0169	91277	-0.0119	0.31
# rs189147642	1	721757	T	A	T	0.963	76627	-0.00827	0.47

# %% [markdown]
# ## Part 3: Filter GWAS summary stats to HapMap3 SNPs (memory efficient)
#
# Why do this?
# - LDSC is commonly run on HapMap3 SNPs to reduce noise and keep runtime/memory manageable.
# - We load the HapMap3 SNP IDs into a `set`, then stream through the gzipped GWAS file line-by-line and write out only matching SNPs.

# %%
filtered_file = tmp_dir / "GERA-sqrtHDL-hm3.tsv.gz"

# Load HapMap3 SNP IDs into a set
with open(hm3_list, "r") as f:
    hm3_snps = {line.split("\t")[0] for line in f if line.strip()}

print(f"Loaded {len(hm3_snps):,} HapMap3 SNP IDs.")

# Stream input and write filtered output
count_in = 0
count_out = 0

with gzip.open(gwas_file, "rt") as f_in, gzip.open(filtered_file, "wt") as f_out:
    header = f_in.readline()
    f_out.write(header)

    for line in f_in:
        count_in += 1
        snp_id = line.split("\t", 1)[0]  # SNP_ID is the first column
        if snp_id in hm3_snps:
            f_out.write(line)
            count_out += 1

print(f"Read {count_in:,} SNPs from the original file.")
print(f"Wrote {count_out:,} HapMap3 SNPs to: {filtered_file}")
# Out:
# Loaded 1,217,312 HapMap3 SNP IDs.
# Read 20,325,718 SNPs from the original file.
# Wrote 1,210,412 HapMap3 SNPs to: tmp/GERA-sqrtHDL-hm3.tsv.gz

# %%
# First few lines of the filtered file
with gzip.open(filtered_file, "rt") as f:
    for i in range(5):
        print(f.readline().rstrip())
# Out:
# SNP_ID	chromosome	position	Allele 1	Allele 2	Effect allele (EA)	Effect allele frequency (EAF)	Sample size	Estimate Effect	P value
# rs3094315	1	752566	G	A	G	0.164	94235	-0.00505	0.32
# rs3131972	1	752721	A	G	A	0.198	94674	-0.000876	0.84
# rs3131969	1	754182	A	G	A	0.172	94674	-0.0013	0.78
# rs1048488	1	760912	C	T	C	0.314	10753	0.0131	0.28

# %% [markdown]
# ## Part 4: Run LD Score Regression (LDSC) using gwaslab
#
# We load the filtered summary stats (HapMap3 SNPs) and run `estimate_h2_by_ldsc()`.
#
# Notes:
# - The summary stats are build hg19 / b37 (gwaslab uses `build="19"` for hg19).
# - `ref_ld_chr` and `w_ld_chr` both point to the same reference directory for this dataset.

# %%
import gwaslab as gl

print("gwaslab version loaded successfully.")

ss = gl.Sumstats(
    str(filtered_file),
    snpid="SNP_ID",
    chrom="chromosome",
    pos="position",
    ea="Effect allele (EA)",
    nea="Allele 2",
    n="Sample size",
    p="P value",
    beta="Estimate Effect",
    build="19",
)

# Basic formatting check
ss.basic_check()
# Out:
# gwaslab version loaded successfully.
# 2026/01/19 12:02:40 GWASLab v4.0.4 https://cloufield.github.io/gwaslab/
# 2026/01/19 12:02:40 (C) 2022-2026, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2026/01/19 12:02:40 Python version: 3.12.12 (main, Oct  9 2025, 11:07:00) [Clang 17.0.0 (clang-1700.4.4.1)]
# 2026/01/19 12:02:40 Start to initialize gl.Sumstats from file :tmp/GERA-sqrtHDL-hm3.tsv.gz
# 2026/01/19 12:02:41  -Reading columns          : SNP_ID,chromosome,Estimate Effect,P value,Allele 2,Sample size,Effect allele (EA),position
# 2026/01/19 12:02:41  -Renaming columns to      : SNPID,CHR,BETA,P,NEA,N,EA,POS
# 2026/01/19 12:02:41  -Current Dataframe shape : 1210412  x  8
# 2026/01/19 12:02:41  -Initiating a status column: STATUS ...
# 2026/01/19 12:02:41  -Genomic coordinates are based on GRCh37/hg19...
# 2026/01/19 12:02:41 Start to reorder the columns ...(v4.0.4)
# 2026/01/19 12:02:41  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,STATUS,BETA,P,N
# 2026/01/19 12:02:41 Finished reordering the columns.
# 2026/01/19 12:02:41  -Trying to convert datatype for CHR: string -> Int64...Success
# 2026/01/19 12:02:41  -Column  : SNPID  CHR   POS   EA       NEA      STATUS BETA    P       N
# 2026/01/19 12:02:41  -DType   : object Int64 int64 category category int64  float64 float64 int64
# 2026/01/19 12:02:41  -Verified: T      T     T     T        T        T      T       T       T
# 2026/01/19 12:02:41  -Current Dataframe memory usage: 68.11 MB
# 2026/01/19 12:02:41 Finished loading data successfully!
# 2026/01/19 12:02:41 Start to check SNPID/rsID ...(v4.0.4)
# 2026/01/19 12:02:41  -Current Dataframe shape : 1210412 x 9 ; Memory usage: 68.11 MB
# 2026/01/19 12:02:41  -Checking SNPID data type...
# 2026/01/19 12:02:41  -Converted datatype for SNPID: object -> string
# 2026/01/19 12:02:41  -Checking if SNPID contains NA strings :na,NA,Na,Nan,NaN,<NA>,null,NULL,#N/A,#VALUE!,N/A,n/a,missing,...
# 2026/01/19 12:02:41  -Checking if SNPID is CHR:POS:NEA:EA...(separator: - ,: , _)
# 2026/01/19 12:02:42 Finished checking SNPID/rsID.
# 2026/01/19 12:02:42 Start to fix chromosome notation (CHR) ...(v4.0.4)
# 2026/01/19 12:02:42  -Checking CHR data type...
# 2026/01/19 12:02:42  -Variants with standardized chromosome notation: 1210412
# 2026/01/19 12:02:42  -All CHR are already fixed...
# 2026/01/19 12:02:42 Finished fixing chromosome notation (CHR).
# 2026/01/19 12:02:42 Start to fix basepair positions (POS) ...(v4.0.4)
# 2026/01/19 12:02:42  -Trying to convert datatype for POS: int64 -> Int64...
# 2026/01/19 12:02:42  -Position bound:(0 , 250,000,000)
# 2026/01/19 12:02:42  -No outlier variants were removed.
# 2026/01/19 12:02:42 Finished fixing basepair positions (POS).
# 2026/01/19 12:02:42 Start to fix alleles (EA and NEA) ...(v4.0.4)
# 2026/01/19 12:02:42  -Converted all bases to string datatype and UPPERCASE
# 2026/01/19 12:02:42  -All variants have valid alleles (EA and NEA are A/C/T/G, not NA, and different).
# 2026/01/19 12:02:43 Finished fixing alleles (EA and NEA).
# 2026/01/19 12:02:43 Start to perform sanity check for statistics ...(v4.0.4)
# 2026/01/19 12:02:43  -Comparison tolerance for floats: 1e-07
# 2026/01/19 12:02:43  -Checking if any columns are empty...
# 2026/01/19 12:02:43  -Checking if 0 <= N <= 2147483647 : removed 0 variants.
# 2026/01/19 12:02:43 #WARNING! Extremely low P detected (P=0 or P < minimum positive value of float64) : 9
# 2026/01/19 12:02:43 #WARNING! Please consider using MLOG10P instead.
# 2026/01/19 12:02:43  -Checking if -1e-07 < P < 1.0000001 : removed 0 variants.
# 2026/01/19 12:02:43  -Checking if -100.0000001 < BETA < 100.0000001 : removed 0 variants.
# 2026/01/19 12:02:43  -Checking STATUS and converting STATUS to Int64....
# 2026/01/19 12:02:43  -No variants were removed with bad statistics in total.
# 2026/01/19 12:02:43 Finished sanity check for statistics.
# 2026/01/19 12:02:43 Start to check data consistency across columns ...(v4.0.4)
# 2026/01/19 12:02:43  -Tolerance: 0.001 (Relative) and 0.001 (Absolute)
# 2026/01/19 12:02:43  -No availalbe columns for data consistency checking...Skipping...
# 2026/01/19 12:02:43 Finished checking data consistency across columns.
# 2026/01/19 12:02:43 Start to normalize indels ...(v4.0.4)
# 2026/01/19 12:02:43  -Number of threads/cores to use: 1
# 2026/01/19 12:02:43  -No available variants to normalize..
# 2026/01/19 12:02:43 Finished normalizing indels.
# 2026/01/19 12:02:43 Start to sort the genome coordinates ...(v4.0.4)
# 2026/01/19 12:02:43 Finished sorting coordinates.
# 2026/01/19 12:02:43 Start to reorder the columns ...(v4.0.4)
# 2026/01/19 12:02:43  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,STATUS,BETA,P,N
# 2026/01/19 12:02:43 Finished reordering the columns.
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SNPID</th>
#       <th>CHR</th>
#       <th>POS</th>
#       <th>EA</th>
#       <th>NEA</th>
#       <th>STATUS</th>
#       <th>BETA</th>
#       <th>P</th>
#       <th>N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>rs3094315</td>
#       <td>1</td>
#       <td>752566</td>
#       <td>G</td>
#       <td>A</td>
#       <td>1980099</td>
#       <td>-0.005050</td>
#       <td>0.3200</td>
#       <td>94235</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>rs3131972</td>
#       <td>1</td>
#       <td>752721</td>
#       <td>A</td>
#       <td>G</td>
#       <td>1980099</td>
#       <td>-0.000876</td>
#       <td>0.8400</td>
#       <td>94674</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>rs3131969</td>
#       <td>1</td>
#       <td>754182</td>
#       <td>A</td>
#       <td>G</td>
#       <td>1980099</td>
#       <td>-0.001300</td>
#       <td>0.7800</td>
#       <td>94674</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>rs1048488</td>
#       <td>1</td>
#       <td>760912</td>
#       <td>C</td>
#       <td>T</td>
#       <td>1980099</td>
#       <td>0.013100</td>
#       <td>0.2800</td>
#       <td>10753</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>rs3115850</td>
#       <td>1</td>
#       <td>761147</td>
#       <td>T</td>
#       <td>C</td>
#       <td>1980099</td>
#       <td>0.013200</td>
#       <td>0.2700</td>
#       <td>10753</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>1210407</th>
#       <td>rs3810648</td>
#       <td>22</td>
#       <td>51175626</td>
#       <td>A</td>
#       <td>G</td>
#       <td>1980099</td>
#       <td>0.012300</td>
#       <td>0.0960</td>
#       <td>87819</td>
#     </tr>
#     <tr>
#       <th>1210408</th>
#       <td>rs2285395</td>
#       <td>22</td>
#       <td>51178090</td>
#       <td>G</td>
#       <td>A</td>
#       <td>1980099</td>
#       <td>0.022500</td>
#       <td>0.0076</td>
#       <td>87819</td>
#     </tr>
#     <tr>
#       <th>1210409</th>
#       <td>rs3865766</td>
#       <td>22</td>
#       <td>51186228</td>
#       <td>C</td>
#       <td>T</td>
#       <td>1980099</td>
#       <td>-0.001900</td>
#       <td>0.8800</td>
#       <td>7795</td>
#     </tr>
#     <tr>
#       <th>1210410</th>
#       <td>rs3888396</td>
#       <td>22</td>
#       <td>51211392</td>
#       <td>T</td>
#       <td>C</td>
#       <td>1980099</td>
#       <td>-0.004100</td>
#       <td>0.7100</td>
#       <td>14650</td>
#     </tr>
#     <tr>
#       <th>1210411</th>
#       <td>rs2238837</td>
#       <td>22</td>
#       <td>51212875</td>
#       <td>A</td>
#       <td>C</td>
#       <td>1980099</td>
#       <td>-0.004660</td>
#       <td>0.7000</td>
#       <td>7795</td>
#     </tr>
#   </tbody>
# </table>
# <p>1210412 rows × 9 columns</p>
# </div>

# %%
results = ss.estimate_h2_by_ldsc(
    ref_ld_chr=str(ref_dir) + "/", w_ld_chr=str(ref_dir) + "/", munge=True
)

# The main output is stored here:
ss.ldsc_h2
# Out:
# 2026/01/19 12:02:43  -Genomic coordinates are based on GRCh37/hg19...
# 2026/01/19 12:02:43 Start to extract HapMap3 SNPs ...(v4.0.4)
# 2026/01/19 12:02:43  -Loading Hapmap3 variants from built-in datasets...
# 2026/01/19 12:02:45  -Since rsID not in sumstats, CHR:POS( build 19) will be used for matching...
# 2026/01/19 12:02:46  -Checking if alleles are same...
# 2026/01/19 12:02:47  -Variants with matched alleles: 1213751
# 2026/01/19 12:02:47  -Raw input contains 1213751 Hapmap3 variants based on CHR:POS...
# 2026/01/19 12:02:47 Finished extracting HapMap3 SNPs.
# 2026/01/19 12:02:47 Start to run LD score regression ...(v4.0.4)
# 2026/01/19 12:02:47  -Current Dataframe shape : 1213751 x 10 ; Memory usage: 85.66 MB
# 2026/01/19 12:02:47 Start to munge sumstats.
# 2026/01/19 12:02:47  -Renamed columns: {'EA': 'A1', 'NEA': 'A2', 'rsID': 'SNP'}
# 2026/01/19 12:02:47  -WARNING: 6658 SNPs had P outside of (0,1]. The P column may be mislabeled.
# 2026/01/19 12:02:47  -After P-value filtering: 1207093 SNPs remain
# 2026/01/19 12:02:47  -After allele filtering (strand-unambiguous): 1207093 SNPs remain
# 2026/01/19 12:02:47 Start to filter palindromic variants ...(v4.0.4)
# 2026/01/19 12:02:47  -Current Dataframe shape : 1207093 x 10 ; Memory usage: 85.19 MB
# 2026/01/19 12:02:47  -Identified palindromic variants: 0
# 2026/01/19 12:02:47  -Filtered out variants: 0
# 2026/01/19 12:02:47 Finished filtering variants.
# 2026/01/19 12:02:47  -After removing palindromic SNPs: 1207093 SNPs remain
# 2026/01/19 12:02:47  -After N filtering (>= 63116.0): 1144112 SNPs remain
# 2026/01/19 12:02:47 Start to exclude variants in HLA regions ...(v4.0.4)
# 2026/01/19 12:02:47  -Current Dataframe shape : 1144112 x 10 ; Memory usage: 80.74 MB
# 2026/01/19 12:02:47  -Excluded 3003 variants in HLA region (chr6: 25000000-34000000 )...
# 2026/01/19 12:02:47  -Filtered out variants: 3003
# 2026/01/19 12:02:47  -Current Dataframe shape : 1141109 x 10 ; Memory usage: 80.53 MB
# 2026/01/19 12:02:47 Finished filtering variants.
# 2026/01/19 12:02:47  -After excluding HLA: 1141109 SNPs remain
# 2026/01/19 12:02:47 Start to exclude variants on sex chromosomes ...(v4.0.4)
# 2026/01/19 12:02:47  -Excluded 0 variants on sex chromosomes ([23, 24, 25])...
# 2026/01/19 12:02:47  -Filtered out variants: 0
# 2026/01/19 12:02:47 Finished filtering variants.
# 2026/01/19 12:02:48  -After excluding sex chromosomes: 1141109 SNPs remain
# 2026/01/19 12:02:48  -Converted P to Z scores
# 2026/01/19 12:02:48  -Munging complete: 72642 SNPs removed, 1141109 SNPs remain (from original 1213751)
# 2026/01/19 12:02:48 Finished munging sumstats.
# 2026/01/19 12:02:48  -Run single variate LD score regression:
# 2026/01/19 12:02:48   -Adopted from LDSC source code: https://github.com/bulik/ldsc
# 2026/01/19 12:02:48   -Please cite LDSC: Bulik-Sullivan, et al. LD Score Regression Distinguishes Confounding from Polygenicity in Genome-Wide Association Studies. Nature Genetics, 2015.
# 2026/01/19 12:02:48  -Arguments:
# 2026/01/19 12:02:48   -ref_ld_chr:tmp/eur_w_ld_chr/
# 2026/01/19 12:02:48   -w_ld_chr:tmp/eur_w_ld_chr/
# 2026/01/19 12:02:48  -LDSC log:
# 2026/01/19 12:02:48   -Reading reference panel LD Score from tmp/eur_w_ld_chr/[1-22] ... (ldscore_fromlist)
# 2026/01/19 12:02:49   -Read reference panel LD Scores for 1290028 SNPs.
# 2026/01/19 12:02:49   -Removing partitioned LD Scores with zero variance.
# 2026/01/19 12:02:49   -Reading regression weight LD Score from tmp/eur_w_ld_chr/[1-22] ... (ldscore_fromlist)
# 2026/01/19 12:02:50   -Read regression weight LD Scores for 1290028 SNPs.
# 2026/01/19 12:02:51   -After merging with reference panel LD, 1122998 SNPs remain.
# 2026/01/19 12:02:52   -After merging with regression SNP LD, 1122998 SNPs remain.
# 2026/01/19 12:02:52   -Using two-step estimator with cutoff at 30.
# 2026/01/19 12:02:52  -Results have been stored in .ldsc_h2
# 2026/01/19 12:02:52 Finished running LD score regression.
#       h2_obs       h2_se   Lambda_gc   Mean_chi2   Intercept Intercept_se  \
# 0  0.2130941  0.02382769  1.25445562  1.46028661  1.04590234   0.01174202
#
#         Ratio    Ratio_se Catagories
# 0  0.09972557  0.02551024         NA

# %% [markdown]
# ## Part 5: 95% Confidence Interval For h²
#
# We compute a 95% CI using:
#
# \[
# h^2 \pm 1.96 \times SE
# \]
#
# Then we interpret what this means in plain language.

# %%
ldsc_out = ss.ldsc_h2
print("Type of ss.ldsc_h2:", type(ldsc_out))
print(ldsc_out)
# Out:
# Type of ss.ldsc_h2: <class 'pandas.core.frame.DataFrame'>
#       h2_obs       h2_se   Lambda_gc   Mean_chi2   Intercept Intercept_se  \
# 0  0.2130941  0.02382769  1.25445562  1.46028661  1.04590234   0.01174202
#
#         Ratio    Ratio_se Catagories
# 0  0.09972557  0.02551024         NA

# %%
import numpy as np
import pandas as pd

ld = ss.ldsc_h2.copy()

# If it's not a DataFrame, stop and we’ll handle it differently
if not isinstance(ld, pd.DataFrame):
    raise TypeError(f"Expected ss.ldsc_h2 to be a DataFrame, got: {type(ld)}")

# normalize column names for searching
col_map = {
    c: c.lower().replace(" ", "").replace("-", "").replace("_", "") for c in ld.columns
}

# candidate patterns
h2_candidates = [
    c
    for c, norm in col_map.items()
    if norm in ("h2", "h2obs", "snph2", "totalh2", "h2total", "h2observed")
]
se_candidates = [
    c
    for c, norm in col_map.items()
    if norm in ("se", "seh2", "h2se", "std", "stderr", "standarderror")
]

print("Possible h2 columns:", h2_candidates)
print("Possible SE columns:", se_candidates)

# pick the first reasonable ones
h2_col = h2_candidates[0] if h2_candidates else None
se_col = se_candidates[0] if se_candidates else None

if h2_col is None or se_col is None:
    raise KeyError(
        "Could not automatically find h2 and SE columns. Paste the 'Columns:' output and I'll tell you exactly which ones to use."
    )

# if there are multiple rows, grab the first row (usually correct for single-trait LDSC)
h2 = float(ld.iloc[0][h2_col])
se = float(ld.iloc[0][se_col])

ci_low = h2 - 1.96 * se
ci_high = h2 + 1.96 * se

print(f"Using columns: h2='{h2_col}', SE='{se_col}'")
print("h2 =", h2)
print("SE =", se)
print("95% CI =", (ci_low, ci_high))
# Out:
# Possible h2 columns: ['h2_obs']
# Possible SE columns: ['h2_se']
# Using columns: h2='h2_obs', SE='h2_se'
# h2 = 0.2130941
# SE = 0.02382769
# 95% CI = (0.16639182760000001, 0.2597963724)

# %% [markdown]
# ## Conclusion: Genome-Wide SNP-based Heritability
#
# Genome-wide SNP-based heritability for square-root–transformed HDL cholesterol was estimated using LD Score Regression implemented in the `gwaslab` package, using European ancestry LD reference panels from the 1000 Genomes Project and restricting analyses to HapMap3 SNPs. The estimated heritability was **h² = 0.21**, with a standard error of **0.024**. A 95% confidence interval was calculated as \( h^2 \pm 1.96 \times SE \), resulting in a confidence interval of **(0.17, 0.26)**. This result suggests that about **21%** of the variation in square-root–transformed HDL cholesterol can be explained by common genetic variants captured by GWAS arrays. The remaining variation is likely due to environmental factors, measurement error, and genetic effects not well captured by common SNPs, such as rare variants. Because this estimate reflects SNP-based (chip) heritability, it is expected to be lower than heritability estimates from twin or family-based studies.
